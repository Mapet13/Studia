-- %% [markdown]
-- > <span style="color: #f78c6c;">8</span>. Podaj nazwy i ceny produktów z kategorii Seafood

-- %%
SELECT 
    ProductName, UnitPrice
FROM 
    Products
WHERE   
    CategoryID IN (
        SELECT 
            CategoryID
        FROM 
            Categories
        WHERE 
            CategoryName = 'Seafood'
    )
-- Out:
-- (12 rows affected)
-- Total execution time: 00:00:00.010
-- <table><tr><th>ProductName</th><th>UnitPrice</th></tr><tr><td>Ikura</td><td>31.0000</td></tr><tr><td>Konbu</td><td>6.0000</td></tr><tr><td>Carnarvon Tigers</td><td>62.5000</td></tr><tr><td>Nord-Ost Matjeshering</td><td>25.8900</td></tr><tr><td>Inlagd Sill</td><td>19.0000</td></tr><tr><td>Gravad lax</td><td>26.0000</td></tr><tr><td>Boston Crab Meat</td><td>18.4000</td></tr><tr><td>Jack's New England Clam Chowder</td><td>9.6500</td></tr><tr><td>Rogede sild</td><td>9.5000</td></tr><tr><td>Spegesild</td><td>12.0000</td></tr><tr><td>Escargots de Bourgogne</td><td>13.2500</td></tr><tr><td>Röd Kaviar</td><td>15.0000</td></tr></table>

-- %% [markdown]
-- > 9\. Podaj ilu jest pracowników, którzy urodzili się przed 1960 rokiem i mieszkają w Londynie.

-- %%
SELECT 
    COUNT(EmployeeID) 
FROM 
    Employees
WHERE
    YEAR(BirthDate) < 1960
    AND
    City = 'London'
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.011
-- <table><tr><th>(No column name)</th></tr><tr><td>1</td></tr></table>

-- %% [markdown]
-- > 10.Podaj dane 5-ciu najstarszych pracowników.

-- %%
SELECT 
    TOP 5 *
FROM 
    Employees
ORDER BY BirthDate ASC
-- Out:
-- (5 rows affected)
-- Total execution time: 00:00:00.024
-- ...

-- %% [markdown]
-- > 11.Podaj ilu jest pracowników, którzy urodzili się pomiędzy latami 1950-1955 lub 1958-60 i mieszkają w Londynie.

-- %%
SELECT 
    COUNT(EmployeeID)
FROM
    Employees
WHERE
    (
        YEAR(BirthDate) BETWEEN 1950 AND 1955
        OR
        YEAR(BirthDate) BETWEEN 1958 AND 1960
    )
    AND
    City = 'London'
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.005
-- <table><tr><th>(No column name)</th></tr><tr><td>2</td></tr></table>

-- %% [markdown]
-- > 12.Wyświetl aktualna listę produktów (atrybut Discontinued)

-- %%
SELECT 
    *
FROM 
    Products 
WHERE 
    Discontinued = 1
-- Out:
-- (8 rows affected)
-- Total execution time: 00:00:00.009
-- ...

-- %% [markdown]
-- > 13.Podaj ID zamówienia oraz ID klienta dla zamówień dokonanych przed 1.09.1996

-- %%
SELECT 
    OrderID, CustomerID 
FROM 
    Orders
WHERE 
    OrderDate < '1996-09-01'
    -- adsa
-- Out:
-- (47 rows affected)
-- Total execution time: 00:00:00.012
-- ...

-- %% [markdown]
-- > 14.Podaj dane klientów, którzy w nazwie mają frazę 'the'

-- %%
SELECT 
    * 
FROM 
    Customers
WHERE 
    CompanyName LIKE '%the%'
-- Out:
-- (3 rows affected)
-- Total execution time: 00:00:00.008
-- <table><tr><th>CustomerID</th><th>CompanyName</th><th>ContactName</th><th>ContactTitle</th><th>Address</th><th>City</th><th>Region</th><th>PostalCode</th><th>Country</th><th>Phone</th><th>Fax</th></tr><tr><td>AROUT</td><td>Around the Horn</td><td>Thomas Hardy</td><td>Sales Representative</td><td>120 Hanover Sq.</td><td>London</td><td>NULL</td><td>WA1 1DP</td><td>UK</td><td>(171) 555-7788</td><td>(171) 555-6750</td></tr><tr><td>THEBI</td><td>The Big Cheese</td><td>Liz Nixon</td><td>Marketing Manager</td><td>89 Jefferson Way Suite 2</td><td>Portland</td><td>OR</td><td>97201</td><td>USA</td><td>(503) 555-3612</td><td>NULL</td></tr><tr><td>THECR</td><td>The Cracker Box</td><td>Liu Wong</td><td>Marketing Assistant</td><td>55 Grizzly Peak Rd.</td><td>Butte</td><td>MT</td><td>59801</td><td>USA</td><td>(406) 555-5834</td><td>(406) 555-8083</td></tr></table>

-- %% [markdown]
-- > 15.Podaj dane klientów, których nazwa zaczyna się na literę 'B' lub 'W'

-- %%
SELECT 
    * 
FROM 
    Customers
WHERE 
    CompanyName LIKE 'B%'
    OR 
    CompanyName LIKE 'W%'
-- Out:
-- (12 rows affected)
-- Total execution time: 00:00:00.065
-- ...

-- %% [markdown]
-- > 16.Podaj dane produktów, których nazwa zaczyna się na literę 'C' lub których productid jest mniejszy niż 40, jednocześnie których cena jest większa niż 20.

-- %%
SELECT 
    * 
FROM 
    Products
WHERE
    (
        ProductName LIKE 'C%'
        OR
        ProductID  < 40
    )
    AND
    UnitPrice  > 20
-- Out:
-- (23 rows affected)
-- Total execution time: 00:00:00.013
-- ...

-- %% [markdown]
-- > 20.Wyświetl dostawców, którzy nie posiadają strony internetowej, nie posiadają faxu, z kraju USA lub Germany

-- %%
SELECT 
    CompanyName
FROM 
    Suppliers
WHERE 
    HomePage IS NULL
    AND
    Fax IS NULL
    AND 
    (
        Country = 'USA'
        OR 
        Country = 'Germany'
    )
-- Out:
-- (2 rows affected)
-- Total execution time: 00:00:00.002
-- <table><tr><th>CompanyName</th></tr><tr><td>Heli Süßwaren GmbH &amp; Co. KG</td></tr><tr><td>Bigfoot Breweries</td></tr></table>

-- %% [markdown]
-- > 21.Podaj ile jest produktów pakowanych w butelki/szkło

-- %%
SELECT
    COUNT(ProductID)
FROM 
    Products
WHERE
    QuantityPerUnit LIKE '%bottle%'
    OR
    QuantityPerUnit LIKE '%glass%'
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.004
-- <table><tr><th>(No column name)</th></tr><tr><td>15</td></tr></table>

-- %% [markdown]
-- > 22.Która kategoria produktów jest najliczniejsza (produkty w kategorii)?

-- %%
SELECT
    CategoryName
FROM 
    Categories
WHERE 
    CategoryID IN (
        SELECT 
            TOP 1 CategoryID
        From 
            Products
        GROUP By 
            CategoryID
        ORDER BY 
            COUNT(ProductID) DESC
    )
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.010
-- <table><tr><th>CategoryName</th></tr><tr><td>Confections</td></tr></table>

-- %% [markdown]
-- > 23.Wyświetl listę kategorii z uwzględnieniem łącznych stanów magazynowych, posortowaną rosnąco.

-- %%
SELECT 
     Categories.CategoryName, SUM(Products.UnitsInStock) AS 'Łączny stan magazynowy'
FROM 
    Categories
INNER JOIN 
    Products
    On Products.CategoryID = Categories.CategoryID
GROUP BY 
   Categories.CategoryName
ORDER BY 
    SUM(Products.UnitsInStock)
-- Out:
-- (8 rows affected)
-- Total execution time: 00:00:00.008
-- <table><tr><th>CategoryName</th><th>Łączny stan magazynowy</th></tr><tr><td>Produce</td><td>100</td></tr><tr><td>Meat/Poultry</td><td>165</td></tr><tr><td>Grains/Cereals</td><td>308</td></tr><tr><td>Confections</td><td>386</td></tr><tr><td>Dairy Products</td><td>393</td></tr><tr><td>Condiments</td><td>507</td></tr><tr><td>Beverages</td><td>559</td></tr><tr><td>Seafood</td><td>701</td></tr></table>
